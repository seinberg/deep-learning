# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

from collections import Counter

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:03, 9.10MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)

# %%
print(words[:100])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term', 'is', 'still', 'used', 'in', 'a', 'pejorative', 'way', 'to', 'describe', 'any', 'act', 'that', 'used', 'violent', 'means', 'to', 'destroy', 'the', 'organization', 'of', 'society', 'it', 'has', 'also', 'been', 'taken', 'up', 'as', 'a', 'positive', 'label', 'by', 'self', 'defined', 'anarchists', 'the', 'word', 'anarchism', 'is', 'derived', 'from', 'the', 'greek', 'without', 'archons', 'ruler', 'chief', 'king', 'anarchism', 'as', 'a', 'political', 'philosophy', 'is', 'the', 'belief', 'that', 'rulers', 'are', 'unnecessary', 'and', 'should', 'be', 'abolished', 'although', 'there', 'are', 'differing']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

word_counts = Counter(int_words)
total_wordcount = len(int_words)
freqs = {word: count/total_wordcount for word, count in word_counts.items()}
threshold = 1e-5

print(int_to_vocab[0])
print("wordcount: {}, vocab size: {}".format(total_wordcount, len(word_counts)))
# Out:
# the
# wordcount: 16680599, vocab size: 63641

# %%
## Your code here

def prob_keep(threshold, word=None, int_word=None):
    if(word is not None):
        int_word = vocab_to_int[word]

    if(int_word is None):
        raise ValueError('must specify either word or int_word')

    return 1 - np.sqrt(threshold / freqs[int_word])

word = 'graham'
int_word = vocab_to_int[word]
print("frequency of {}: {}".format(word, freqs[int_word]))
keep_prob = prob_keep(threshold, word=word)
rand_num = random.random()
print("prob of dropping {} is {}. keep? {} (using {} as comparison)".format(word, keep_prob, keep_prob <= rand_num, rand_num))

int_word_probs = [prob_keep(threshold, int_word=int_word) for int_word in set(int_words)]
train_words = [int_word for int_word in int_words if (int_word_probs[int_word] < random.random())]
# Out:
# frequency of graham: 2.1941658090335964e-05
# prob of dropping graham is 0.324904398593613. keep? True (using 0.42078311495910115 as comparison)

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''

    r = random.randint(1, window_size+1)
    if (idx - r) < 0:
        return words[0:idx+r+1]
    return words[idx-r:idx+r+1]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer because we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None])
    labels = tf.placeholder(tf.int32, [None, None])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], minval=-1, maxval=1))
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros(n_vocab))

    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 100
batch_size = 1000
window_size = 15

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/100 Iteration: 100 Avg. Training loss: 5.5862 0.0791 sec/batch
# Epoch 1/100 Iteration: 200 Avg. Training loss: 5.5356 0.0785 sec/batch
# Epoch 1/100 Iteration: 300 Avg. Training loss: 5.3692 0.0783 sec/batch
# Epoch 1/100 Iteration: 400 Avg. Training loss: 5.4393 0.0783 sec/batch
# Epoch 1/100 Iteration: 500 Avg. Training loss: 5.3265 0.0781 sec/batch
# Epoch 1/100 Iteration: 600 Avg. Training loss: 5.3144 0.0787 sec/batch
# Epoch 1/100 Iteration: 700 Avg. Training loss: 5.3120 0.0784 sec/batch
# Epoch 1/100 Iteration: 800 Avg. Training loss: 5.2928 0.0788 sec/batch
# Epoch 1/100 Iteration: 900 Avg. Training loss: 5.2360 0.0784 sec/batch
# Epoch 1/100 Iteration: 1000 Avg. Training loss: 5.1512 0.0789 sec/batch
# Nearest to his: counteroffensive, darwinism, stresses, optimal, borrelly, angiosperms, preceded, burdened,
# Nearest to zero: monads, shadow, sutherland, pushing, solemnity, ascii, hemorrhage, enemies,
# Nearest to two: casually, gershwin, flow, resolution, dispense, whereas, honshu, lutetium,
# Nearest to were: messalina, exogamy, whatsoever, parasite, infects, rudin, vivekananda, complexity,
# Nearest to be: aoun, obtainable, goalkeepers, escu, anno, calibrate, estate, quiet,
# Nearest to also: rasul, malwa, sumner, declarative, cabins, kubitschek, renga, humphries,
# Nearest to but: calories, swimming, mysteriously, oran, sweetcorn, mayan, individual, sanctions,
# Nearest to that: unscathed, girl, strabo, destroying, bewitched, walled, riverboats, even,
# Nearest to pope: driving, percieved, arlen, rampart, len, petition, geometry, roundly,
# Nearest to hold: discounting, moors, namek, wickedness, comma, comb, tann, syngman,
# Nearest to test: unchained, shaper, meant, cathedral, regimes, assyria, nuremberg, corvinus,
# Nearest to older: violins, braxton, hurling, gustav, hirobumi, solis, cyclops, angelika,
# Nearest to powers: wavefunction, involve, keystrokes, wrc, boys, noumenon, slaughterhouse, faq,
# Nearest to channel: only, comprehensibility, termination, dynes, kazak, nil, notepad, untouchables,
# Nearest to versions: webmail, draped, unsatisfactory, souvenir, performances, boyne, portable, digging,
# Nearest to liberal: nlds, shoemakers, langdon, informally, hacks, corona, calf, kirby,
# Epoch 1/100 Iteration: 1100 Avg. Training loss: 5.1961 0.0804 sec/batch
# Epoch 1/100 Iteration: 1200 Avg. Training loss: 5.0779 0.0791 sec/batch
# Epoch 1/100 Iteration: 1300 Avg. Training loss: 5.0221 0.0790 sec/batch
# Epoch 1/100 Iteration: 1400 Avg. Training loss: 4.9366 0.0789 sec/batch
# Epoch 1/100 Iteration: 1500 Avg. Training loss: 4.9095 0.0789 sec/batch
# Epoch 1/100 Iteration: 1600 Avg. Training loss: 4.8836 0.0815 sec/batch
# Epoch 1/100 Iteration: 1700 Avg. Training loss: 4.8280 0.0852 sec/batch
# Epoch 1/100 Iteration: 1800 Avg. Training loss: 4.7616 0.0837 sec/batch
# Epoch 1/100 Iteration: 1900 Avg. Training loss: 4.7905 0.0844 sec/batch
# Epoch 1/100 Iteration: 2000 Avg. Training loss: 4.7483 0.0836 sec/batch
# Nearest to his: counteroffensive, optimal, stresses, preceded, darwinism, borrelly, subscribe, creating,
# Nearest to zero: monads, shadow, patterns, sutherland, being, culture, pushing, enemies,
# Nearest to two: flow, whereas, resolution, gershwin, casually, supervision, candles, ferdinand,
# Nearest to were: messalina, parasite, exogamy, whatsoever, complexity, comes, herndon, appendages,
# Nearest to be: aoun, quiet, estate, obtainable, undergrowth, calibrate, smith, practical,
# Nearest to also: rasul, says, cabins, declarative, sumner, remedy, elected, subjects,
# Nearest to but: swimming, calories, individual, tigers, brewery, sanctions, figures, mysteriously,
# Nearest to that: girl, walled, unscathed, an, even, strabo, destroying, link,
# Nearest to pope: driving, arlen, geometry, petition, len, concern, percieved, shore,
# Nearest to hold: moors, isolation, discounting, dangerously, offices, turn, wickedness, comma,
# Nearest to test: meant, unchained, cathedral, shaper, regimes, nuremberg, commodities, turbulence,
# Nearest to older: violins, braxton, gustav, besides, considered, boyce, facts, solis,
# Nearest to powers: involve, wavefunction, specific, wrc, boys, faq, keystrokes, require,
# Nearest to channel: only, comprehensibility, termination, kazak, dynes, nil, size, correspond,
# Nearest to versions: webmail, draped, performances, l, portable, connected, souvenir, boyne,
# Nearest to liberal: nlds, langdon, hacks, shoemakers, informally, silurian, corona, kirby,
# Epoch 1/100 Iteration: 2100 Avg. Training loss: 4.6897 0.0819 sec/batch
# Epoch 1/100 Iteration: 2200 Avg. Training loss: 4.7005 0.0813 sec/batch
# Epoch 1/100 Iteration: 2300 Avg. Training loss: 4.6693 0.0812 sec/batch
# Epoch 1/100 Iteration: 2400 Avg. Training loss: 4.6674 0.0816 sec/batch
# Epoch 1/100 Iteration: 2500 Avg. Training loss: 4.6047 0.0815 sec/batch
# Epoch 1/100 Iteration: 2600 Avg. Training loss: 4.6082 0.0806 sec/batch
# Epoch 1/100 Iteration: 4000 Avg. Training loss: 4.4494 0.0811 sec/batch
# Nearest to his: counteroffensive, reconquer, optimal, burdened, preceded, darwinism, angiosperms, gravelines,
# Nearest to zero: monads, two, shadow, belknap, underside, sutherland, marburg, sambia,
# Nearest to two: zero, honshu, ferdinand, york, gershwin, harsher, albert, probate,
# Nearest to were: messalina, whatsoever, parasite, semitic, sorbs, exogamy, herndon, sexes,
# Nearest to be: indistinguishable, anteater, quiet, aoun, goalkeepers, tardis, obtainable, practical,
# Nearest to also: rasul, declarative, malwa, sumner, cabins, remedy, blind, shamir,
# Nearest to but: calories, mysteriously, swimming, mayan, arrears, sweetcorn, individual, tigers,
# Nearest to that: walled, even, descend, contradiction, freely, unscathed, cromwell, ineffectual,
# Nearest to pope: driving, arlen, geometry, len, starring, percieved, petition, partridge,
# Nearest to hold: wickedness, discounting, moors, isolation, bicameral, offices, gallifrey, comb,
# Nearest to test: unchained, meant, shaper, tracks, aye, sustaining, nuremberg, cathedral,
# Nearest to older: braxton, violins, hurling, sundry, solis, boyce, gustav, angelika,
# Nearest to powers: wavefunction, keystrokes, faq, slaughterhouse, migrations, discretion, boys, specific,
# Nearest to channel: comprehensibility, termination, only, nil, dynes, untouchables, kazak, notepad,
# Nearest to versions: webmail, portable, draped, unsatisfactory, souvenir, connected, boyne, performances,
# Nearest to liberal: nlds, langdon, informally, shoemakers, hacks, silurian, calf, sportspeople,
# Epoch 1/100 Iteration: 4100 Avg. Training loss: 4.4614 0.0818 sec/batch
# Epoch 1/100 Iteration: 4200 Avg. Training loss: 4.4824 0.0809 sec/batch
# Epoch 80/100 Iteration: 366700 Avg. Training loss: 3.4602 0.0830 sec/batch
# Epoch 80/100 Iteration: 366800 Avg. Training loss: 3.5567 0.0835 sec/batch
# Epoch 80/100 Iteration: 366900 Avg. Training loss: 3.5024 0.0809 sec/batch
# Epoch 80/100 Iteration: 367000 Avg. Training loss: 3.5080 0.0814 sec/batch
# Nearest to his: he, him, himself, son, successor, career, autobiography, grandson,
# Nearest to zero: five, two, seven, four, one, three, isbn, six,
# Nearest to two: four, zero, three, one, five, six, eight, nine,
# Nearest to were: was, had, abandoned, later, their, additionally, profitable, thousands,
# Nearest to be: require, can, to, got, this, there, your, someone,
# Nearest to also: of, where, indirectly, see, tend, he, named, major,
# Nearest to but: any, outright, opponents, replaced, absence, rather, appear, operates,
# Nearest to that: claiming, assumed, suggest, there, argued, preserve, claims, assume,
# Nearest to pope: papacy, coptic, alexander, innocent, antipope, alexandria, xiii, gregory,
# Nearest to hold: holds, em, apart, many, considered, will, reject, other,
# Nearest to test: tests, testing, launch, inspiration, england, ashes, constraints, experimental,
# Nearest to older: household, age, versus, average, median, income, males, females,
# Nearest to powers: possess, superhuman, mutant, telekinetic, manipulate, abacus, dc, perceptions,
# Nearest to channel: channels, broadcasting, programmes, aired, viewers, television, broadcaster, broadcasts,
# Nearest to versions: version, brewery, derivatives, variant, clover, blofeld, introduced, translations,
# Nearest to liberal: liberals, party, democrats, conservative, democrat, parties, liberalism, conservatives,
# Epoch 80/100 Iteration: 367100 Avg. Training loss: 3.5589 0.0827 sec/batch
# Epoch 80/100 Iteration: 367200 Avg. Training loss: 3.5947 0.0823 sec/batch
# Epoch 80/100 Iteration: 367300 Avg. Training loss: 3.5228 0.0831 sec/batch
# Epoch 80/100 Iteration: 367400 Avg. Training loss: 3.5677 0.0817 sec/batch
# Epoch 80/100 Iteration: 367500 Avg. Training loss: 3.6214 0.0809 sec/batch
# Epoch 80/100 Iteration: 367600 Avg. Training loss: 3.5676 0.0827 sec/batch
# Epoch 80/100 Iteration: 367700 Avg. Training loss: 3.5477 0.0814 sec/batch
# Epoch 80/100 Iteration: 367800 Avg. Training loss: 3.5314 0.0819 sec/batch
# Epoch 80/100 Iteration: 367900 Avg. Training loss: 3.5757 0.0804 sec/batch
# Epoch 80/100 Iteration: 368000 Avg. Training loss: 3.5473 0.0813 sec/batch
# Nearest to his: he, career, him, himself, son, moved, outline, succeeded,
# Nearest to zero: two, five, four, seven, one, three, september, isbn,
# Nearest to two: four, three, zero, six, eight, five, one, nine,
# Nearest to were: was, had, developed, rumoured, additionally, profitable, abandoned, blame,
# Nearest to be: require, someone, to, can, your, got, much, strictly,
# Nearest to also: of, website, see, indirectly, based, including, who, named,
# Nearest to but: replaced, any, opponents, or, outright, is, it, think,
# Nearest to that: claiming, able, argued, stated, argue, assume, suggest, say,
# Nearest to pope: papacy, catholic, orthodox, gregory, papal, innocent, alexander, pius,
# Nearest to hold: holds, apart, considered, subsequent, is, crucial, many, utilize,
# Nearest to test: tests, testing, launch, experimentation, tested, constraints, first, inspiration,
# Nearest to older: household, versus, median, age, average, income, females, males,
# Nearest to powers: possess, territorial, defeat, telekinetic, physical, aura, imperialist, abacus,
# Nearest to channel: channels, broadcasting, aired, programmes, broadcaster, tv, nbc, broadcasts,
# Nearest to versions: version, brewery, replace, ranges, with, clover, newer, blofeld,
# Nearest to liberal: liberals, democrats, parties, party, democrat, democratic, liberalism, conservative,
# Epoch 80/100 Iteration: 368100 Avg. Training loss: 3.5920 0.0831 sec/batch
# Epoch 80/100 Iteration: 368200 Avg. Training loss: 3.5775 0.0842 sec/batch
# Epoch 80/100 Iteration: 368300 Avg. Training loss: 3.5502 0.0840 sec/batch
# Epoch 80/100 Iteration: 368400 Avg. Training loss: 3.5744 0.0854 sec/batch
# Epoch 80/100 Iteration: 368500 Avg. Training loss: 3.6065 0.0806 sec/batch
# Epoch 80/100 Iteration: 368600 Avg. Training loss: 3.5996 0.0832 sec/batch
# Epoch 80/100 Iteration: 368700 Avg. Training loss: 3.5631 0.0837 sec/batch
# Epoch 80/100 Iteration: 368800 Avg. Training loss: 3.5892 0.0836 sec/batch
# Epoch 80/100 Iteration: 368900 Avg. Training loss: 3.5408 0.0839 sec/batch
# Epoch 80/100 Iteration: 369000 Avg. Training loss: 3.6014 0.0847 sec/batch
# Nearest to his: he, career, successor, credited, spent, him, artist, succeeded,
# Nearest to zero: five, two, four, one, isbn, seven, three, six,
# Nearest to two: three, four, zero, six, five, eight, one, nine,
# Nearest to were: was, aware, laid, deported, eliminated, died, blame, encouraged,
# Nearest to be: require, to, can, someone, got, serve, your, remain,
# Nearest to also: of, indirectly, website, around, went, who, topics, named,
# Nearest to but: does, any, replaced, outright, offering, it, opponents, is,
# Nearest to that: argue, claiming, open, there, argued, feared, sufficient, imply,
# Nearest to pope: papacy, papal, rome, fuga, antipope, gregory, coptic, pius,
# Nearest to hold: holds, views, initially, crucial, apart, subsequent, utilize, over,
# Nearest to test: tests, testing, environment, match, tested, inspiration, launch, july,
# Nearest to older: household, versus, age, median, average, newer, younger, who,
# Nearest to powers: possess, defeat, magicians, mutant, superhuman, zone, territorial, transferred,
# Nearest to channel: channels, broadcasting, aired, networks, broadcasts, broadcaster, nbc, programmes,
# Nearest to versions: version, brewery, translations, entry, updated, clover, replace, newer,
# Nearest to liberal: democrat, liberals, conservative, liberalism, democrats, parties, centrist, party,
# Epoch 80/100 Iteration: 369100 Avg. Training loss: 3.6122 0.0854 sec/batch
# Epoch 80/100 Iteration: 369200 Avg. Training loss: 3.6661 0.0834 sec/batch
# Epoch 80/100 Iteration: 369300 Avg. Training loss: 3.6094 0.0848 sec/batch
# Epoch 80/100 Iteration: 369400 Avg. Training loss: 3.6080 0.0851 sec/batch
# Epoch 80/100 Iteration: 369500 Avg. Training loss: 3.5521 0.0837 sec/batch
# Epoch 80/100 Iteration: 369600 Avg. Training loss: 3.4849 0.0842 sec/batch
# Epoch 80/100 Iteration: 369700 Avg. Training loss: 3.5505 0.0834 sec/batch
# Epoch 80/100 Iteration: 369800 Avg. Training loss: 3.5194 0.0840 sec/batch
# Epoch 80/100 Iteration: 369900 Avg. Training loss: 3.6279 0.0838 sec/batch
# Epoch 80/100 Iteration: 370000 Avg. Training loss: 3.5792 0.0846 sec/batch
# Nearest to his: him, he, himself, credited, career, spent, son, travelled,
# Nearest to zero: two, five, one, four, female, seven, male, net,
# Nearest to two: three, zero, four, six, one, eight, five, nine,
# Nearest to were: was, november, eliminated, blame, wwii, there, load, additionally,
# Nearest to be: to, require, can, remain, nevertheless, strictly, someone, traced,
# Nearest to also: of, indirectly, tend, particularly, topics, website, who, went,
# Nearest to but: replaced, any, stability, mainly, it, opponents, standing, does,
# Nearest to that: claiming, there, suggest, say, able, focusing, imply, create,
# Nearest to pope: papacy, papal, cardinal, innocent, luther, alexander, antipope, benedict,
# Nearest to hold: five, crucial, initially, holds, utilize, apart, rarely, over,
# Nearest to test: tests, testing, launch, match, inspiration, monitor, selected, tested,
# Nearest to older: household, age, versus, median, younger, average, females, households,
# Nearest to powers: possess, zone, telekinetic, magicians, manipulate, learns, transform, magical,
# Nearest to channel: channels, broadcasting, aired, nbc, broadcaster, broadcasts, programmes, television,
# Nearest to versions: version, newer, introduced, updated, operating, brewery, appealing, replace,
# Nearest to liberal: liberalism, liberals, democrats, conservative, parties, politics, democrat, centrist,
# Epoch 80/100 Iteration: 370100 Avg. Training loss: 3.5162 0.0855 sec/batch
# Epoch 81/100 Iteration: 370200 Avg. Training loss: 3.6386 0.0346 sec/batch
# Epoch 81/100 Iteration: 370300 Avg. Training loss: 3.5891 0.0842 sec/batch
# Epoch 81/100 Iteration: 370400 Avg. Training loss: 3.5733 0.0841 sec/batch
# Epoch 81/100 Iteration: 370500 Avg. Training loss: 3.5903 0.0845 sec/batch
# Epoch 81/100 Iteration: 370600 Avg. Training loss: 3.6027 0.0839 sec/batch
# Epoch 81/100 Iteration: 370700 Avg. Training loss: 3.5619 0.0838 sec/batch
# Epoch 81/100 Iteration: 370800 Avg. Training loss: 3.5638 0.0840 sec/batch
# Epoch 81/100 Iteration: 370900 Avg. Training loss: 3.5159 0.0843 sec/batch
# Epoch 81/100 Iteration: 371000 Avg. Training loss: 3.6121 0.0869 sec/batch
# Nearest to his: him, he, spent, career, himself, son, travelled, friend,
# Nearest to zero: two, five, female, deaths, seven, one, births, male,
# Nearest to two: four, zero, three, one, five, eight, six, seven,
# Nearest to were: was, november, abandoned, smaller, wwii, later, had, feared,
# Nearest to be: require, to, someone, can, remain, got, should, traced,
# Nearest to also: indirectly, of, named, went, tend, including, he, directly,
# Nearest to but: any, debated, standing, mainly, widely, rather, absence, delivered,
# Nearest to that: there, claiming, able, on, stating, was, indeed, suggest,
# Nearest to pope: papacy, innocent, coptic, alexander, papal, bull, gregory, orthodox,
# Nearest to hold: holds, five, apart, separation, having, is, reject, coset,
# Nearest to test: tests, testing, launch, tested, july, selected, match, cancelled,
# Nearest to older: household, versus, age, median, newer, younger, average, males,
# Nearest to powers: transform, territories, telekinetic, magicians, possess, aftermath, territorial, accordion,
# Nearest to channel: channels, broadcasting, aired, nbc, broadcaster, cable, programmes, broadcasts,
# Nearest to versions: version, brewery, newer, serco, improved, manufactured, replace, variants,
# Nearest to liberal: liberals, liberalism, democrats, conservative, politics, parties, party, centrist,
# Epoch 81/100 Iteration: 371100 Avg. Training loss: 3.5600 0.0849 sec/batch
# Epoch 81/100 Iteration: 371200 Avg. Training loss: 3.6214 0.0837 sec/batch
# Epoch 81/100 Iteration: 371300 Avg. Training loss: 3.5098 0.0840 sec/batch
# Epoch 81/100 Iteration: 371400 Avg. Training loss: 3.5407 0.0850 sec/batch
# Epoch 81/100 Iteration: 371500 Avg. Training loss: 3.5540 0.0839 sec/batch
# Epoch 81/100 Iteration: 371600 Avg. Training loss: 3.4293 0.0835 sec/batch
# Epoch 81/100 Iteration: 371700 Avg. Training loss: 3.5391 0.0845 sec/batch
# Epoch 81/100 Iteration: 371800 Avg. Training loss: 3.6072 0.0845 sec/batch
# Epoch 81/100 Iteration: 371900 Avg. Training loss: 3.5417 0.0843 sec/batch
# Epoch 81/100 Iteration: 372000 Avg. Training loss: 3.5431 0.0835 sec/batch
# Nearest to his: he, him, career, son, credited, himself, succeeded, work,
# Nearest to zero: five, two, seven, one, female, births, isbn, four,
# Nearest to two: four, three, zero, one, eight, five, six, nine,
# Nearest to were: was, found, there, had, combined, abandoned, members, later,
# Nearest to be: require, to, can, recognized, your, as, drop, remain,
# Nearest to also: of, named, see, such, tend, who, lead, went,
# Nearest to but: any, replaced, is, debated, mainly, it, does, absence,
# Nearest to that: claiming, there, argue, suggest, take, stating, focusing, preserve,
# Nearest to pope: papacy, papal, antipope, alexander, coptic, innocent, luther, popes,
# Nearest to hold: other, except, crucial, will, holds, em, apart, considered,
# Nearest to test: tests, testing, tested, inspiration, criterion, constraints, resolved, launch,
# Nearest to older: household, versus, average, newer, age, median, income, households,
# Nearest to powers: telekinetic, physical, occupying, magical, mutant, rumelia, integral, possess,
# Nearest to channel: channels, broadcasting, programmes, broadcasts, aired, broadcaster, bbc, viewers,
# Nearest to versions: version, brewery, sold, ms, variant, newer, latest, replace,
# Nearest to liberal: liberals, liberalism, democrats, parties, party, conservatives, conservative, centrist,
# Epoch 81/100 Iteration: 372100 Avg. Training loss: 3.6038 0.0848 sec/batch
# Epoch 81/100 Iteration: 372200 Avg. Training loss: 3.6242 0.0832 sec/batch
# Epoch 81/100 Iteration: 372300 Avg. Training loss: 3.5269 0.0827 sec/batch
# Epoch 81/100 Iteration: 372400 Avg. Training loss: 3.5491 0.0818 sec/batch
# Epoch 81/100 Iteration: 372500 Avg. Training loss: 3.5964 0.0814 sec/batch
# Epoch 81/100 Iteration: 372600 Avg. Training loss: 3.6058 0.0834 sec/batch
# Epoch 81/100 Iteration: 372700 Avg. Training loss: 3.5220 0.0836 sec/batch
# Epoch 81/100 Iteration: 372800 Avg. Training loss: 3.5509 0.0802 sec/batch
# Epoch 81/100 Iteration: 372900 Avg. Training loss: 3.5819 0.0839 sec/batch
# Epoch 81/100 Iteration: 373000 Avg. Training loss: 3.5634 0.0844 sec/batch
# Nearest to his: him, career, he, credited, attending, spent, himself, son,
# Nearest to zero: two, five, net, female, male, one, september, four,
# Nearest to two: three, zero, four, eight, six, one, five, february,
# Nearest to were: was, abandoned, had, members, these, parts, eliminated, managed,
# Nearest to be: require, to, can, must, traced, future, although, someone,
# Nearest to also: of, indirectly, named, topics, for, list, are, went,
# Nearest to but: replaced, any, debated, does, extant, mainly, widely, rather,
# Nearest to that: argue, claiming, argued, there, bring, suggest, sufficient, assumed,
# Nearest to pope: papacy, papal, coptic, innocent, orthodox, luther, relics, pius,
# Nearest to hold: holds, other, lending, will, except, crucial, five, separation,
# Nearest to test: tests, testing, tested, launch, inspiration, nuclear, hazardous, endangered,
# Nearest to older: household, versus, age, average, newer, median, who, below,
# Nearest to powers: telekinetic, territorial, integral, territories, aura, accordion, magical, telepaths,
# Nearest to channel: channels, broadcasting, programmes, cable, nbc, broadcaster, wb, tunnel,
# Nearest to versions: version, brewery, translations, ms, newer, replace, saying, figures,
# Nearest to liberal: democrats, liberals, parties, liberalism, centrist, conservatives, democrat, party,
# Epoch 81/100 Iteration: 373100 Avg. Training loss: 3.5875 0.0828 sec/batch
# Epoch 81/100 Iteration: 373200 Avg. Training loss: 3.5758 0.0816 sec/batch
# Epoch 81/100 Iteration: 373300 Avg. Training loss: 3.5949 0.0822 sec/batch
# Epoch 81/100 Iteration: 373400 Avg. Training loss: 3.5406 0.0800 sec/batch
# Epoch 81/100 Iteration: 373500 Avg. Training loss: 3.5287 0.0800 sec/batch
# Epoch 81/100 Iteration: 373600 Avg. Training loss: 3.5672 0.0818 sec/batch
# Epoch 81/100 Iteration: 373700 Avg. Training loss: 3.5853 0.0829 sec/batch
# Epoch 81/100 Iteration: 373800 Avg. Training loss: 3.6482 0.0824 sec/batch
# Epoch 81/100 Iteration: 373900 Avg. Training loss: 3.6405 0.0835 sec/batch
# Epoch 81/100 Iteration: 374000 Avg. Training loss: 3.5829 0.0823 sec/batch
# Nearest to his: career, he, him, himself, spent, credited, son, appearances,
# Nearest to zero: two, five, female, net, isbn, male, three, one,
# Nearest to two: zero, three, four, six, one, eight, five, isbn,
# Nearest to were: feared, was, had, these, parts, died, found, later,
# Nearest to be: require, to, can, traced, remain, serve, kelley, requirement,
# Nearest to also: of, named, indirectly, tend, around, list, topics, went,
# Nearest to but: any, replaced, debated, outright, period, mainly, dwindled, larger,
# Nearest to that: focusing, argue, there, claiming, suggest, feared, argued, follow,
# Nearest to pope: papacy, papal, cardinal, luther, innocent, alexander, xvi, catholic,
# Nearest to hold: holds, agree, is, other, lending, mostly, considered, lha,
# Nearest to test: tests, testing, match, hazardous, validity, distribution, inspiration, selected,
# Nearest to older: age, household, average, newer, versus, median, younger, who,
# Nearest to powers: telekinetic, manipulate, abilities, possess, dominate, aura, integral, transform,
# Nearest to channel: channels, broadcasting, broadcasts, programmes, cable, aired, tunnel, wb,
# Nearest to versions: version, revised, brewery, unfinished, translations, restart, ten, kyrie,
# Nearest to liberal: democrat, liberals, liberalism, democrats, democratic, party, conservative, centrist,
# Epoch 81/100 Iteration: 374100 Avg. Training loss: 3.6126 0.0834 sec/batch
# Epoch 81/100 Iteration: 374200 Avg. Training loss: 3.4898 0.0818 sec/batch
# Epoch 81/100 Iteration: 374300 Avg. Training loss: 3.5131 0.0830 sec/batch
# Epoch 81/100 Iteration: 374400 Avg. Training loss: 3.4854 0.0827 sec/batch
# Epoch 81/100 Iteration: 374500 Avg. Training loss: 3.6317 0.0830 sec/batch
# Epoch 81/100 Iteration: 374600 Avg. Training loss: 3.5804 0.0826 sec/batch
# Epoch 81/100 Iteration: 374700 Avg. Training loss: 3.5683 0.0829 sec/batch
# Epoch 82/100 Iteration: 374800 Avg. Training loss: 3.5753 0.0115 sec/batch
# Epoch 82/100 Iteration: 374900 Avg. Training loss: 3.5852 0.0823 sec/batch
# Epoch 82/100 Iteration: 375000 Avg. Training loss: 3.5630 0.0830 sec/batch
# Nearest to his: he, him, son, himself, career, spent, travelled, friend,
# Nearest to zero: two, five, one, female, seven, net, four, male,
# Nearest to two: three, zero, four, six, five, one, eight, isbn,
# Nearest to were: was, later, november, had, been, abandoned, died, found,
# Nearest to be: to, require, can, traced, as, stated, must, strictly,
# Nearest to also: of, tend, named, indirectly, usual, are, directly, occasionally,
# Nearest to but: any, widely, disputed, period, mainly, does, happen, is,
# Nearest to that: there, assumed, focusing, interested, inconsistent, claiming, suggest, argue,
# Nearest to pope: papacy, papal, luther, cardinal, innocent, relics, xii, sixtus,
# Nearest to hold: holds, reject, lending, considered, having, endless, other, is,
# Nearest to test: tests, testing, match, ashes, inspiration, launch, series, describing,
# Nearest to older: age, household, newer, younger, average, grew, median, versus,
# Nearest to powers: telekinetic, possess, dominate, mckinley, abilities, domination, differently, licensing,
# Nearest to channel: channels, broadcasting, aired, programmes, cable, broadcasts, radio, wb,
# Nearest to versions: version, brewery, beijing, revised, operating, papas, figures, unfinished,
# Nearest to liberal: liberalism, liberals, conservative, democrats, conservatives, centrist, party, parties,
# Epoch 82/100 Iteration: 375100 Avg. Training loss: 3.5830 0.0843 sec/batch
# Epoch 82/100 Iteration: 375200 Avg. Training loss: 3.6014 0.0824 sec/batch
# Epoch 82/100 Iteration: 375300 Avg. Training loss: 3.5309 0.0825 sec/batch
# Epoch 82/100 Iteration: 375400 Avg. Training loss: 3.5701 0.0826 sec/batch
# Epoch 82/100 Iteration: 375500 Avg. Training loss: 3.5417 0.0819 sec/batch
# Epoch 82/100 Iteration: 375600 Avg. Training loss: 3.5842 0.0846 sec/batch
# Epoch 82/100 Iteration: 375700 Avg. Training loss: 3.5854 0.0820 sec/batch
# Epoch 82/100 Iteration: 375800 Avg. Training loss: 3.6033 0.0856 sec/batch
# Epoch 82/100 Iteration: 375900 Avg. Training loss: 3.5571 0.0821 sec/batch
# Epoch 82/100 Iteration: 376000 Avg. Training loss: 3.5516 0.0834 sec/batch
# Nearest to his: he, him, himself, grandson, spent, succeeded, career, wanted,
# Nearest to zero: two, five, seven, male, four, female, deaths, births,
# Nearest to two: zero, three, four, eight, five, one, six, seven,
# Nearest to were: parts, was, abandoned, combined, rejected, these, been, smaller,
# Nearest to be: require, to, must, got, can, remain, someone, as,
# Nearest to also: of, indirectly, see, named, includes, list, major, website,
# Nearest to but: any, does, widely, replaced, is, standing, or, debated,
# Nearest to that: there, assumed, claiming, such, bring, suggest, might, take,
# Nearest to pope: papacy, alexander, papal, innocent, coptic, cardinal, xiii, orthodox,
# Nearest to hold: em, is, will, other, considered, holds, apart, lending,
# Nearest to test: tests, testing, hazardous, ashes, match, tested, parameters, inspiration,
# Nearest to older: household, age, newer, younger, versus, income, median, males,
# Nearest to powers: territory, possess, exceeds, telekinetic, authority, mckinley, territorial, territories,
# Nearest to channel: channels, programmes, broadcasting, bbc, tunnel, ireland, aired, broadcasts,
# Nearest to versions: version, translations, operating, improved, brewery, crisis, revised, variants,
# Nearest to liberal: democrats, liberals, liberalism, party, conservative, democrat, centrist, parties,
# Epoch 82/100 Iteration: 376100 Avg. Training loss: 3.5404 0.0841 sec/batch
# Epoch 82/100 Iteration: 376200 Avg. Training loss: 3.4594 0.0827 sec/batch
# Epoch 82/100 Iteration: 376300 Avg. Training loss: 3.5203 0.0823 sec/batch
# Epoch 82/100 Iteration: 376400 Avg. Training loss: 3.5584 0.0825 sec/batch
# Epoch 82/100 Iteration: 376500 Avg. Training loss: 3.5515 0.0838 sec/batch
# Epoch 82/100 Iteration: 376600 Avg. Training loss: 3.5544 0.0828 sec/batch
# Epoch 82/100 Iteration: 376700 Avg. Training loss: 3.5898 0.0825 sec/batch
# Epoch 82/100 Iteration: 376800 Avg. Training loss: 3.5945 0.0833 sec/batch
# Epoch 82/100 Iteration: 376900 Avg. Training loss: 3.5397 0.0833 sec/batch
# Epoch 82/100 Iteration: 377000 Avg. Training loss: 3.5593 0.0835 sec/batch
# Nearest to his: he, career, began, appeared, himself, wanted, him, returning,
# Nearest to zero: five, two, four, three, male, female, one, deaths,
# Nearest to two: three, four, zero, eight, one, five, six, nine,
# Nearest to were: was, found, had, later, lived, abandoned, there, been,
# Nearest to be: require, to, can, choose, manner, serve, must, desirable,
# Nearest to also: named, of, includes, website, indirectly, around, such, for,
# Nearest to but: any, replaced, remained, debated, it, widely, or, mainly,
# Nearest to that: claiming, there, explains, focusing, take, certain, might, bring,
# Nearest to pope: papacy, papal, popes, alexander, cardinal, orthodox, sixtus, coptic,
# Nearest to hold: holds, is, em, other, considered, five, separation, over,
# Nearest to test: tests, testing, tested, hazardous, inspiration, criterion, significant, selected,
# Nearest to older: household, versus, age, income, median, males, females, average,
# Nearest to powers: telekinetic, telescoping, exceeds, possess, transferred, integral, mckinley, territory,
# Nearest to channel: channels, broadcasting, programmes, broadcasts, bbc, tunnel, aired, broadcast,
# Nearest to versions: version, translations, brewery, newer, variants, revised, replace, entry,
# Nearest to liberal: liberals, democrats, party, liberalism, democrat, parties, democratic, conservative,
# Epoch 82/100 Iteration: 377100 Avg. Training loss: 3.5764 0.0850 sec/batch
# Epoch 82/100 Iteration: 377200 Avg. Training loss: 3.5800 0.0831 sec/batch
# Epoch 82/100 Iteration: 377300 Avg. Training loss: 3.5302 0.0799 sec/batch
# Epoch 82/100 Iteration: 377400 Avg. Training loss: 3.6004 0.0798 sec/batch
# Epoch 82/100 Iteration: 377500 Avg. Training loss: 3.6125 0.0800 sec/batch
# Epoch 82/100 Iteration: 377600 Avg. Training loss: 3.5389 0.0799 sec/batch
# Epoch 82/100 Iteration: 377700 Avg. Training loss: 3.5971 0.0798 sec/batch
# Epoch 82/100 Iteration: 377800 Avg. Training loss: 3.6130 0.0793 sec/batch
# Epoch 82/100 Iteration: 377900 Avg. Training loss: 3.5551 0.0804 sec/batch
# Epoch 82/100 Iteration: 378000 Avg. Training loss: 3.5555 0.0829 sec/batch
# Nearest to his: he, him, spent, career, succeeded, apparently, appeared, himself,
# Nearest to zero: five, two, net, seven, four, three, one, september,
# Nearest to two: three, four, zero, eight, five, six, nine, seven,
# Nearest to were: was, lived, had, parts, later, abandoned, there, eliminated,
# Nearest to be: require, to, can, drop, remain, much, manner, as,
# Nearest to also: of, list, named, website, are, for, indirectly, around,
# Nearest to but: any, replaced, remained, widely, or, period, outright, is,
# Nearest to that: there, focusing, claiming, suggest, argue, such, consensus, explains,
# Nearest to pope: papacy, papal, cardinal, alexander, popes, xiii, pius, sixtus,
# Nearest to hold: holds, over, other, considered, five, is, mostly, invalidate,
# Nearest to test: tests, testing, tested, hazardous, inspiration, experimentation, ashes, ralph,
# Nearest to older: age, household, versus, median, females, income, average, newer,
# Nearest to powers: telescoping, manipulate, possess, telekinetic, abilities, magical, dominate, domination,
# Nearest to channel: channels, broadcasting, programmes, cable, aired, bbc, broadcasts, broadcaster,
# Nearest to versions: version, newer, replace, translations, operating, revised, brewery, exception,
# Nearest to liberal: liberals, democrats, party, liberalism, conservatives, democrat, parties, centrist,
# Epoch 82/100 Iteration: 378100 Avg. Training loss: 3.5572 0.0844 sec/batch
# Epoch 82/100 Iteration: 378200 Avg. Training loss: 3.5155 0.0827 sec/batch
# Epoch 82/100 Iteration: 378300 Avg. Training loss: 3.6341 0.0843 sec/batch
# Epoch 82/100 Iteration: 378400 Avg. Training loss: 3.6391 0.0850 sec/batch
# Epoch 82/100 Iteration: 378500 Avg. Training loss: 3.6345 0.0838 sec/batch
# Epoch 82/100 Iteration: 378600 Avg. Training loss: 3.5905 0.0838 sec/batch
# Epoch 82/100 Iteration: 378700 Avg. Training loss: 3.6052 0.0828 sec/batch
# Epoch 82/100 Iteration: 378800 Avg. Training loss: 3.5055 0.0814 sec/batch
# Epoch 82/100 Iteration: 378900 Avg. Training loss: 3.5358 0.0825 sec/batch
# Epoch 82/100 Iteration: 379000 Avg. Training loss: 3.5291 0.0830 sec/batch
# Nearest to his: him, he, himself, spent, career, son, friend, appeared,
# Nearest to zero: two, five, net, female, seven, one, male, six,
# Nearest to two: zero, three, four, six, five, eight, one, nine,
# Nearest to were: november, had, camps, parts, found, there, abandoned, heavily,
# Nearest to be: to, require, can, got, drop, there, confused, must,
# Nearest to also: of, for, indirectly, website, in, list, named, topics,
# Nearest to but: any, outright, replaced, remained, debated, stability, period, or,
# Nearest to that: there, able, focusing, claiming, suggest, argued, follow, say,
# Nearest to pope: papacy, papal, alexander, popes, gregory, sixtus, benedict, xiii,
# Nearest to hold: other, is, holds, books, emmanuel, five, separation, considered,
# Nearest to test: tests, testing, tested, hazardous, headingley, failures, match, smirnov,
# Nearest to older: household, age, versus, average, females, there, poverty, median,
# Nearest to powers: mutant, territory, territorial, fell, manipulate, domination, possess, telekinetic,
# Nearest to channel: channels, broadcasting, cable, aired, networks, bbc, nielsen, broadcaster,
# Nearest to versions: version, operating, revised, widely, brewery, files, replace, drivers,
# Nearest to liberal: liberals, liberalism, democrats, conservative, outlook, libertarianism, centrist, politics,
# Epoch 82/100 Iteration: 379100 Avg. Training loss: 3.5620 0.0828 sec/batch
# Epoch 82/100 Iteration: 379200 Avg. Training loss: 3.5854 0.0814 sec/batch
# Epoch 82/100 Iteration: 379300 Avg. Training loss: 3.5548 0.0826 sec/batch
# Epoch 82/100 Iteration: 379400 Avg. Training loss: 3.5717 0.0845 sec/batch
# Epoch 83/100 Iteration: 379500 Avg. Training loss: 3.5915 0.0732 sec/batch
# Epoch 83/100 Iteration: 379600 Avg. Training loss: 3.5929 0.0844 sec/batch
# Epoch 83/100 Iteration: 379700 Avg. Training loss: 3.5908 0.0842 sec/batch
# Epoch 83/100 Iteration: 379800 Avg. Training loss: 3.5791 0.0853 sec/batch
# Epoch 83/100 Iteration: 379900 Avg. Training loss: 3.5538 0.0844 sec/batch
# Epoch 83/100 Iteration: 380000 Avg. Training loss: 3.5720 0.0849 sec/batch
# Nearest to his: he, him, himself, spent, career, succeeded, son, appeared,
# Nearest to zero: two, five, seven, three, six, four, one, net,
# Nearest to two: three, zero, four, five, six, eight, one, seven,
# Nearest to were: was, later, abandoned, had, these, lived, november, found,
# Nearest to be: to, require, can, there, confused, got, stated, must,
# Nearest to also: of, indirectly, see, named, website, tend, uncomfortable, for,
# Nearest to but: any, mainly, debated, widely, outright, standing, remained, proven,
# Nearest to that: claiming, there, able, suggest, extremely, follow, focusing, assumed,
# Nearest to pope: papacy, alexander, papal, gregory, pius, popes, benedict, innocent,
# Nearest to hold: apart, five, other, emmanuel, separation, holds, against, is,
# Nearest to test: tests, testing, tested, flight, match, launch, hazardous, apollo,
# Nearest to older: household, age, versus, average, females, males, poverty, there,
# Nearest to powers: telekinetic, exceeds, mutant, territory, domination, manipulate, transferred, possess,
# Nearest to channel: channels, broadcasting, cable, pbs, broadcaster, broadcasts, radio, aired,
# Nearest to versions: version, improved, operating, replace, introduced, newer, stated, beijing,
# Nearest to liberal: liberals, liberalism, democrats, conservative, centrist, politics, taxation, democrat,
# Epoch 83/100 Iteration: 380100 Avg. Training loss: 3.5359 0.0863 sec/batch
# Epoch 83/100 Iteration: 380200 Avg. Training loss: 3.5648 0.0844 sec/batch
# Epoch 83/100 Iteration: 380300 Avg. Training loss: 3.5569 0.0853 sec/batch
# Epoch 83/100 Iteration: 380400 Avg. Training loss: 3.5947 0.0847 sec/batch
# Epoch 83/100 Iteration: 380500 Avg. Training loss: 3.5928 0.0852 sec/batch
# Epoch 83/100 Iteration: 380600 Avg. Training loss: 3.4900 0.0868 sec/batch
# Epoch 83/100 Iteration: 380700 Avg. Training loss: 3.5675 0.0863 sec/batch
# Epoch 83/100 Iteration: 380800 Avg. Training loss: 3.4939 0.0854 sec/batch
# Epoch 83/100 Iteration: 380900 Avg. Training loss: 3.5116 0.0849 sec/batch
# Epoch 83/100 Iteration: 381000 Avg. Training loss: 3.5509 0.0836 sec/batch
# Nearest to his: he, himself, him, career, wife, outline, died, son,
# Nearest to zero: two, five, seven, four, net, deaths, six, three,
# Nearest to two: four, three, zero, eight, six, one, five, nine,
# Nearest to were: was, had, abandoned, later, found, november, parts, counterparts,
# Nearest to be: require, to, can, as, there, recognized, should, desirable,
# Nearest to also: of, indirectly, website, named, such, tend, potentially, see,
# Nearest to but: any, doesn, debated, opponents, does, outright, much, standing,
# Nearest to that: able, claiming, there, suggest, focusing, assumed, out, might,
# Nearest to pope: papacy, papal, popes, alexander, pius, innocent, benedict, monastery,
# Nearest to hold: em, apart, is, considered, other, holds, except, will,
# Nearest to test: tests, testing, tested, match, union, inspiration, constraints, flight,
# Nearest to older: household, age, versus, average, income, females, median, males,
# Nearest to powers: territory, exceeds, possess, gain, differently, magical, recruit, granted,
# Nearest to channel: channels, broadcasting, programmes, broadcaster, aired, bbc, viewers, broadcasts,
# Nearest to versions: version, improved, brewery, introduction, newer, revised, crisis, beijing,
# Nearest to liberal: democrats, liberals, liberalism, conservative, centrist, party, democrat, conservatives,
# Epoch 83/100 Iteration: 381100 Avg. Training loss: 3.5926 0.0863 sec/batch
# Epoch 83/100 Iteration: 381200 Avg. Training loss: 3.5733 0.0847 sec/batch
# Epoch 83/100 Iteration: 381300 Avg. Training loss: 3.5674 0.0857 sec/batch
# Epoch 83/100 Iteration: 381400 Avg. Training loss: 3.5926 0.0851 sec/batch
# Epoch 83/100 Iteration: 381500 Avg. Training loss: 3.5574 0.0862 sec/batch
# Epoch 83/100 Iteration: 381600 Avg. Training loss: 3.5802 0.0888 sec/batch
# Epoch 83/100 Iteration: 381700 Avg. Training loss: 3.5352 0.0848 sec/batch
# Epoch 83/100 Iteration: 381800 Avg. Training loss: 3.5812 0.0856 sec/batch
# Epoch 83/100 Iteration: 381900 Avg. Training loss: 3.5788 0.0850 sec/batch
# Epoch 83/100 Iteration: 382000 Avg. Training loss: 3.5849 0.0843 sec/batch
# Nearest to his: he, career, him, himself, spent, outline, life, wanted,
# Nearest to zero: two, five, four, seven, three, september, six, net,
# Nearest to two: three, four, zero, six, eight, five, one, seven,
# Nearest to were: was, had, later, developed, november, parts, ones, counterparts,
# Nearest to be: require, can, to, there, someone, possibility, your, above,
# Nearest to also: of, potentially, indirectly, website, single, are, such, uncomfortable,
# Nearest to but: any, debated, replaced, outright, time, does, opponents, operates,
# Nearest to that: able, claiming, might, focusing, suggest, explains, certain, there,
# Nearest to pope: papacy, papal, alexander, gregory, popes, xii, benedict, pius,
# Nearest to hold: holds, apart, owed, god, invalidate, other, mostly, subsequent,
# Nearest to test: tests, testing, match, tested, hazardous, website, union, validity,
# Nearest to older: household, age, average, versus, income, median, poverty, males,
# Nearest to powers: possess, telekinetic, territory, gain, exceeds, differently, telepaths, mutant,
# Nearest to channel: broadcasting, channels, broadcasts, aired, grandparent, bbc, broadcaster, fet,
# Nearest to versions: version, newer, operating, widely, brewery, entry, improved, extend,
# Nearest to liberal: democrats, liberalism, centrist, liberals, party, democrat, european, democratic,
# Epoch 83/100 Iteration: 382100 Avg. Training loss: 3.6034 0.0856 sec/batch
# Epoch 83/100 Iteration: 382200 Avg. Training loss: 3.5622 0.0846 sec/batch
# Epoch 83/100 Iteration: 382300 Avg. Training loss: 3.5920 0.0850 sec/batch
# Epoch 83/100 Iteration: 382400 Avg. Training loss: 3.6030 0.0850 sec/batch
# Epoch 83/100 Iteration: 382500 Avg. Training loss: 3.5811 0.0869 sec/batch
# Epoch 83/100 Iteration: 382600 Avg. Training loss: 3.5425 0.0844 sec/batch
# Epoch 83/100 Iteration: 382700 Avg. Training loss: 3.5841 0.0855 sec/batch
# Epoch 83/100 Iteration: 382800 Avg. Training loss: 3.5258 0.0857 sec/batch
# Epoch 83/100 Iteration: 382900 Avg. Training loss: 3.6478 0.0864 sec/batch
# Epoch 83/100 Iteration: 383000 Avg. Training loss: 3.6072 0.0853 sec/batch
# Nearest to his: he, career, him, appeared, himself, spent, life, autobiography,
# Nearest to zero: five, two, seven, four, three, one, six, isbn,
# Nearest to two: four, three, zero, eight, six, one, nine, five,
# Nearest to were: was, abandoned, november, had, later, lived, developed, there,
# Nearest to be: require, to, can, serve, confused, possibility, there, got,
# Nearest to also: of, named, website, indirectly, list, single, topics, in,
# Nearest to but: any, replaced, debated, remained, outright, widely, opponents, much,
# Nearest to that: claiming, there, assumed, able, explains, follow, feared, focusing,
# Nearest to pope: papacy, papal, alexander, gregory, xii, popes, luther, benedict,
# Nearest to hold: holds, favor, mostly, considered, assumed, owed, endless, deliberately,
# Nearest to test: tests, testing, match, tested, vi, union, ban, mode,
# Nearest to older: household, age, income, versus, poverty, average, median, newer,
# Nearest to powers: possess, differently, telepaths, telekinetic, manipulate, imperialist, zone, steak,
# Nearest to channel: channels, broadcasting, broadcaster, radio, bbc, cable, deployed, acquisition,
# Nearest to versions: version, operating, brewery, zur, newer, putonghua, revised, die,
# Nearest to liberal: democrats, conservative, liberalism, party, liberals, democratic, centrist, democrat,
# Epoch 83/100 Iteration: 383100 Avg. Training loss: 3.6784 0.0874 sec/batch
# Epoch 83/100 Iteration: 383200 Avg. Training loss: 3.5720 0.0851 sec/batch
# Epoch 83/100 Iteration: 383300 Avg. Training loss: 3.6454 0.0845 sec/batch
# Epoch 83/100 Iteration: 383400 Avg. Training loss: 3.5166 0.0821 sec/batch
# Epoch 83/100 Iteration: 383500 Avg. Training loss: 3.4712 0.0805 sec/batch
# Epoch 83/100 Iteration: 383600 Avg. Training loss: 3.5750 0.0800 sec/batch
# Epoch 83/100 Iteration: 383700 Avg. Training loss: 3.5273 0.0813 sec/batch
# Epoch 83/100 Iteration: 383800 Avg. Training loss: 3.6073 0.0846 sec/batch
# Epoch 83/100 Iteration: 383900 Avg. Training loss: 3.5774 0.0814 sec/batch
# Epoch 83/100 Iteration: 384000 Avg. Training loss: 3.5696 0.0819 sec/batch
# Nearest to his: him, he, career, himself, appeared, son, prolific, artist,
# Nearest to zero: two, five, one, four, seven, three, six, april,
# Nearest to two: three, zero, four, six, one, five, eight, nine,
# Nearest to were: parts, was, found, had, these, later, there, abandoned,
# Nearest to be: require, to, can, there, remain, someone, must, traced,
# Nearest to also: of, roles, miscellaneous, topics, named, tend, directly, indirectly,
# Nearest to but: any, remained, replaced, outright, standing, or, completely, proven,
# Nearest to that: claiming, able, follow, focusing, say, might, there, explains,
# Nearest to pope: papacy, papal, alexander, luther, gregory, xii, popes, cardinal,
# Nearest to hold: crucial, holds, assumed, endless, considered, muslims, five, is,
# Nearest to test: tests, match, testing, mode, hazardous, application, describing, comprehensive,
# Nearest to older: household, age, versus, average, income, poverty, newer, there,
# Nearest to powers: possess, telekinetic, zone, extensions, manipulate, telepaths, differently, accordion,
# Nearest to channel: channels, broadcasting, aired, radio, bbc, pbs, viewers, cable,
# Nearest to versions: version, operating, ms, newer, update, improved, updated, windows,
# Nearest to liberal: liberalism, democrats, liberals, party, centrist, politics, democratic, symbolist,
# Epoch 84/100 Iteration: 384100 Avg. Training loss: 3.6025 0.0493 sec/batch
# Epoch 84/100 Iteration: 384200 Avg. Training loss: 3.5759 0.0819 sec/batch
# Epoch 84/100 Iteration: 384300 Avg. Training loss: 3.5796 0.0802 sec/batch
# Epoch 84/100 Iteration: 384400 Avg. Training loss: 3.5898 0.0807 sec/batch
# Epoch 84/100 Iteration: 384500 Avg. Training loss: 3.5386 0.0819 sec/batch
# Epoch 84/100 Iteration: 384600 Avg. Training loss: 3.5540 0.0815 sec/batch
# Epoch 84/100 Iteration: 384700 Avg. Training loss: 3.5204 0.0807 sec/batch
# Epoch 84/100 Iteration: 384800 Avg. Training loss: 3.5430 0.0818 sec/batch
# Epoch 84/100 Iteration: 384900 Avg. Training loss: 3.5817 0.0831 sec/batch
# Epoch 84/100 Iteration: 385000 Avg. Training loss: 3.5139 0.0825 sec/batch
# Nearest to his: him, himself, career, he, son, cousin, succeeded, father,
# Nearest to zero: two, five, seven, female, net, births, deaths, four,
# Nearest to two: four, zero, three, six, one, five, eight, seven,
# Nearest to were: was, november, abandoned, later, parts, these, had, developed,
# Nearest to be: require, to, someone, there, must, can, remain, should,
# Nearest to also: of, named, roles, website, multiple, see, miscellaneous, major,
# Nearest to but: any, remained, standing, outright, opponents, debated, does, or,
# Nearest to that: claiming, explains, there, assumed, able, on, suggest, follow,
# Nearest to pope: alexander, papal, coptic, papacy, xii, luther, popes, gregory,
# Nearest to hold: five, apart, is, considered, view, having, holds, other,
# Nearest to test: tests, testing, match, tested, launch, final, remotely, july,
# Nearest to older: household, age, versus, newer, younger, average, males, poverty,
# Nearest to powers: rol, accordion, possess, governed, androgynous, domination, distrust, granted,
# Nearest to channel: broadcasting, channels, nbc, aired, bbc, pbs, talk, cbs,
# Nearest to versions: version, improved, revised, operating, update, newer, introduced, standard,
# Nearest to liberal: democrats, liberals, party, liberalism, centrist, conservative, election, democrat,
# Epoch 84/100 Iteration: 385100 Avg. Training loss: 3.6333 0.0849 sec/batch
# Epoch 84/100 Iteration: 385200 Avg. Training loss: 3.5194 0.0811 sec/batch
# Epoch 84/100 Iteration: 385300 Avg. Training loss: 3.5514 0.0814 sec/batch
# Epoch 84/100 Iteration: 385400 Avg. Training loss: 3.5074 0.0825 sec/batch
# Epoch 84/100 Iteration: 385500 Avg. Training loss: 3.4580 0.0808 sec/batch
# Epoch 84/100 Iteration: 385600 Avg. Training loss: 3.5747 0.0812 sec/batch
# Epoch 84/100 Iteration: 385700 Avg. Training loss: 3.5775 0.0821 sec/batch
# Epoch 84/100 Iteration: 385800 Avg. Training loss: 3.5865 0.0812 sec/batch
# Epoch 84/100 Iteration: 385900 Avg. Training loss: 3.5324 0.0818 sec/batch
# Epoch 84/100 Iteration: 386000 Avg. Training loss: 3.6400 0.0821 sec/batch
# Nearest to his: him, he, himself, career, son, cousin, childhood, publishing,
# Nearest to zero: two, five, one, seven, births, estimated, female, four,
# Nearest to two: four, three, zero, one, six, eight, nine, five,
# Nearest to were: was, abandoned, later, had, additionally, disrupted, found, there,
# Nearest to be: require, to, someone, can, desirable, as, must, recognized,
# Nearest to also: of, website, named, see, directly, roles, went, such,
# Nearest to but: replaced, remained, does, any, opponents, is, or, debated,
# Nearest to that: claiming, explains, said, able, argue, extremely, doubled, suggest,
# Nearest to pope: alexander, papal, papacy, xii, luther, popes, coptic, cardinal,
# Nearest to hold: em, considered, is, employed, except, apart, greyface, other,
# Nearest to test: tests, testing, match, tested, constraints, resolved, comprehensive, inspiration,
# Nearest to older: household, versus, age, income, average, poverty, males, newer,
# Nearest to powers: physical, possess, telepaths, mutant, gain, respectively, rol, governed,
# Nearest to channel: channels, broadcasting, aired, programmes, viewers, broadcasts, radio, bbc,
# Nearest to versions: version, revised, entry, variant, improved, standard, birth, introduced,
# Nearest to liberal: liberals, democrats, party, liberalism, centrist, conservative, democrat, conservatives,
# Epoch 84/100 Iteration: 386100 Avg. Training loss: 3.5988 0.0835 sec/batch
# Epoch 84/100 Iteration: 386200 Avg. Training loss: 3.5647 0.0837 sec/batch
# Epoch 84/100 Iteration: 386300 Avg. Training loss: 3.5479 0.0831 sec/batch
# Epoch 84/100 Iteration: 386400 Avg. Training loss: 3.5833 0.0832 sec/batch
# Epoch 84/100 Iteration: 386500 Avg. Training loss: 3.5668 0.0829 sec/batch
# Epoch 84/100 Iteration: 386600 Avg. Training loss: 3.5808 0.0836 sec/batch
# Epoch 84/100 Iteration: 386700 Avg. Training loss: 3.6004 0.0825 sec/batch
# Epoch 84/100 Iteration: 386800 Avg. Training loss: 3.5636 0.0825 sec/batch
# Epoch 84/100 Iteration: 386900 Avg. Training loss: 3.5904 0.0824 sec/batch
# Epoch 84/100 Iteration: 387000 Avg. Training loss: 3.5813 0.0822 sec/batch
# Nearest to his: he, him, career, himself, began, spent, prolific, appeared,
# Nearest to zero: two, five, net, female, four, one, seven, male,
# Nearest to two: zero, three, four, six, one, five, eight, seven,
# Nearest to were: was, parts, deported, camps, abandoned, there, marked, november,
# Nearest to be: require, serve, to, as, can, possibility, someone, there,
# Nearest to also: of, see, website, topics, such, list, named, for,
# Nearest to but: replaced, is, remained, any, outright, debated, rather, time,
# Nearest to that: claiming, focusing, explains, sufficient, able, argued, follow, there,
# Nearest to pope: papacy, papal, alexander, luther, gregory, popes, cardinal, xiii,
# Nearest to hold: considered, endless, is, mostly, flared, holds, tough, em,
# Nearest to test: tests, testing, hazardous, tested, match, ban, dumping, nuclear,
# Nearest to older: household, versus, age, average, income, who, newer, poverty,
# Nearest to powers: parliamentary, belgium, possess, benito, transferred, adolf, relinquished, governed,
# Nearest to channel: channels, broadcasting, aired, bbc, nbc, broadcast, radio, viewers,
# Nearest to versions: version, entry, newer, ms, translations, brewery, revised, ter,
# Nearest to liberal: liberals, democrats, party, liberalism, democratic, democrat, conservative, conservatives,
# Epoch 84/100 Iteration: 387100 Avg. Training loss: 3.5767 0.0835 sec/batch
# Epoch 84/100 Iteration: 387200 Avg. Training loss: 3.5864 0.0828 sec/batch
# Epoch 84/100 Iteration: 387300 Avg. Training loss: 3.5597 0.0833 sec/batch
# Epoch 84/100 Iteration: 387400 Avg. Training loss: 3.5466 0.0834 sec/batch
# Epoch 84/100 Iteration: 387500 Avg. Training loss: 3.5858 0.0840 sec/batch
# Epoch 84/100 Iteration: 387600 Avg. Training loss: 3.6220 0.0821 sec/batch
# Epoch 84/100 Iteration: 387700 Avg. Training loss: 3.6710 0.0812 sec/batch
# Epoch 84/100 Iteration: 387800 Avg. Training loss: 3.6352 0.0818 sec/batch
# Epoch 84/100 Iteration: 387900 Avg. Training loss: 3.6143 0.0820 sec/batch
# Epoch 84/100 Iteration: 388000 Avg. Training loss: 3.5773 0.0811 sec/batch
# Nearest to his: he, him, career, credited, appeared, son, prolific, spent,
# Nearest to zero: two, five, female, four, three, one, seven, male,
# Nearest to two: zero, three, four, six, one, eight, five, nine,
# Nearest to were: deported, november, parts, was, feared, resisted, depended, abandoned,
# Nearest to be: to, require, can, as, remain, temporary, serve, possibility,
# Nearest to also: of, list, in, indirectly, around, miscellaneous, directly, topics,
# Nearest to but: remained, any, outright, replaced, does, completely, effective, larger,
# Nearest to that: claiming, able, sufficient, focusing, feared, there, cabriolet, follow,
# Nearest to pope: papacy, alexander, papal, cardinal, popes, antipope, john, downing,
# Nearest to hold: considered, holds, mostly, crucial, is, antinomianism, dominated, view,
# Nearest to test: tests, testing, match, hazardous, ban, endangered, tested, just,
# Nearest to older: household, age, versus, average, income, poverty, females, males,
# Nearest to powers: possess, fell, physical, create, manipulate, unrest, mutant, transferred,
# Nearest to channel: channels, broadcasting, aired, bbc, radio, broadcaster, cable, nbc,
# Nearest to versions: version, revised, stuck, crisis, entry, page, updated, putonghua,
# Nearest to liberal: liberalism, democrats, liberals, party, democratic, centrist, libertarianism, outlook,
# Epoch 84/100 Iteration: 388100 Avg. Training loss: 3.4507 0.0819 sec/batch
# Epoch 84/100 Iteration: 388200 Avg. Training loss: 3.5496 0.0810 sec/batch
# Epoch 84/100 Iteration: 388300 Avg. Training loss: 3.4686 0.0815 sec/batch
# Epoch 84/100 Iteration: 388400 Avg. Training loss: 3.6179 0.0819 sec/batch
# Epoch 84/100 Iteration: 388500 Avg. Training loss: 3.5740 0.0824 sec/batch
# Epoch 84/100 Iteration: 388600 Avg. Training loss: 3.5473 0.0819 sec/batch
# Epoch 85/100 Iteration: 388700 Avg. Training loss: 3.6360 0.0271 sec/batch
# Epoch 85/100 Iteration: 388800 Avg. Training loss: 3.5424 0.0834 sec/batch
# Epoch 85/100 Iteration: 388900 Avg. Training loss: 3.5780 0.0832 sec/batch
# Epoch 85/100 Iteration: 389000 Avg. Training loss: 3.6006 0.0831 sec/batch
# Nearest to his: him, he, himself, son, spent, successor, succeeded, widow,
# Nearest to zero: two, five, three, seven, one, four, female, net,
# Nearest to two: three, zero, four, six, five, one, nine, eight,
# Nearest to were: was, had, abandoned, later, found, there, feared, removed,
# Nearest to be: can, to, require, someone, as, this, temporary, serve,
# Nearest to also: of, named, directly, see, in, topics, website, roles,
# Nearest to but: remained, mainly, any, disputed, rather, happen, is, does,
# Nearest to that: able, claiming, there, follow, sufficient, assumed, said, suggest,
# Nearest to pope: alexander, papacy, papal, john, innocent, xii, vi, popes,
# Nearest to hold: considered, crucial, holds, view, is, books, against, neuroleptic,
# Nearest to test: tests, testing, launch, tested, series, match, flight, ashes,
# Nearest to older: age, household, versus, males, average, there, newer, married,
# Nearest to powers: territories, mckinley, abacus, distrust, divided, accordion, mutant, create,
# Nearest to channel: channels, broadcasting, aired, cable, radio, nbc, pbs, network,
# Nearest to versions: version, acknowledged, improved, ms, crisis, putonghua, ninth, revised,
# Nearest to liberal: liberals, democrats, party, liberalism, centrist, democratic, outlook, conservative,
# Epoch 85/100 Iteration: 389100 Avg. Training loss: 3.5669 0.0846 sec/batch
# Epoch 85/100 Iteration: 389200 Avg. Training loss: 3.5450 0.0814 sec/batch
# Epoch 85/100 Iteration: 389300 Avg. Training loss: 3.5988 0.0810 sec/batch
# Epoch 85/100 Iteration: 389400 Avg. Training loss: 3.5296 0.0807 sec/batch
# Epoch 88/100 Iteration: 402600 Avg. Training loss: 3.6313 0.0413 sec/batch
# Epoch 88/100 Iteration: 402700 Avg. Training loss: 3.5586 0.0819 sec/batch
# Epoch 88/100 Iteration: 402800 Avg. Training loss: 3.6045 0.0821 sec/batch
# Epoch 88/100 Iteration: 402900 Avg. Training loss: 3.5648 0.0825 sec/batch
# Epoch 88/100 Iteration: 403000 Avg. Training loss: 3.5768 0.0857 sec/batch
# Nearest to his: himself, he, him, succeeded, successor, son, father, undertook,
# Nearest to zero: two, five, seven, one, three, six, september, four,
# Nearest to two: three, zero, four, one, six, five, eight, seven,
# Nearest to were: was, involved, been, these, all, portions, originally, there,
# Nearest to be: to, can, require, remain, someone, must, as, got,
# Nearest to also: of, tend, around, directly, uses, comes, major, list,
# Nearest to but: any, larger, replaced, rather, period, distinction, widely, does,
# Nearest to that: claiming, able, was, sufficient, said, say, such, there,
# Nearest to pope: papacy, papal, popes, monastery, luther, innocent, antipope, alexander,
# Nearest to hold: apart, holds, subsequent, other, owed, is, assumed, separation,
# Nearest to test: tests, testing, tested, match, launch, hazardous, launches, july,
# Nearest to older: household, age, who, there, females, versus, size, poverty,
# Nearest to powers: manipulate, governed, superhuman, abilities, territory, augustus, azathoth, magical,
# Nearest to channel: channels, nbc, cable, broadcasting, nai, aired, broadcaster, pbs,
# Nearest to versions: version, introduced, with, stated, prove, ms, the, putonghua,
# Nearest to liberal: liberals, liberalism, democrats, centrist, democrat, conservatives, politics, democratic,
# Epoch 88/100 Iteration: 403100 Avg. Training loss: 3.5586 0.0868 sec/batch
# Epoch 88/100 Iteration: 403200 Avg. Training loss: 3.5713 0.0835 sec/batch
# Epoch 88/100 Iteration: 403300 Avg. Training loss: 3.5398 0.0815 sec/batch
# Epoch 88/100 Iteration: 403400 Avg. Training loss: 3.6221 0.0824 sec/batch
# Epoch 88/100 Iteration: 403500 Avg. Training loss: 3.5433 0.0807 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
